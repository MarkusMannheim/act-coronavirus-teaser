# %%
# modules
import pandas as pd
import io, requests
from PyPDF2 import PdfFileReader

# establish database
data = pd.DataFrame(columns=["date", "first", "second"])
date = pd.to_datetime("2021-08-28")

# begin cycle
while True:
    print(f"checking {date:%b %d, %Y} ...")
    url = f"https://www.health.gov.au/sites/default/files/documents/{date:%Y}/{date:%m}/covid-19-vaccine-rollout-update-{date:%-d-%B-%Y}.pdf".lower()
    try:
        request = requests.get(url)
        file = io.BytesIO(request.content)
        reader = PdfFileReader(file)
        if date > pd.to_datetime("2021-08-15"):
            contents = reader.getPage(5).extractText().split("\n")
        else:
            contents = reader.getPage(2).extractText().split("\n")
        try:
            first = contents[contents.index("dose 1") + 2]
            second = contents[contents.index("dose 2") + 2]
        except:
            first = contents[contents.index("-dose 1") + 2]
            second = contents[contents.index("-dose 2") + 2]            
        data.loc[len(data)] = [date, first, second]            
        date = date - pd.Timedelta(days=1)
        if date < pd.to_datetime("2021-07-2"):
            break
    except:
        print("no data available")
        print(url)
        break
        
data
# Out:
# checking Aug 28, 2021 ...
# checking Aug 27, 2021 ...
# checking Aug 26, 2021 ...
# checking Aug 25, 2021 ...
# checking Aug 24, 2021 ...
# checking Aug 23, 2021 ...
# checking Aug 22, 2021 ...
# checking Aug 21, 2021 ...
# checking Aug 20, 2021 ...
# checking Aug 19, 2021 ...
# checking Aug 18, 2021 ...
# checking Aug 17, 2021 ...
# checking Aug 16, 2021 ...
# checking Aug 15, 2021 ...
# checking Aug 14, 2021 ...
# checking Aug 13, 2021 ...
# checking Aug 12, 2021 ...
# checking Aug 11, 2021 ...
# checking Aug 10, 2021 ...
# checking Aug 09, 2021 ...
# checking Aug 08, 2021 ...
# checking Aug 07, 2021 ...
# checking Aug 06, 2021 ...
# checking Aug 05, 2021 ...
# checking Aug 04, 2021 ...
# checking Aug 03, 2021 ...
# checking Aug 02, 2021 ...
# checking Aug 01, 2021 ...
# checking Jul 31, 2021 ...
# checking Jul 30, 2021 ...
# checking Jul 29, 2021 ...
# checking Jul 28, 2021 ...
# checking Jul 27, 2021 ...
# checking Jul 26, 2021 ...
# checking Jul 25, 2021 ...
# checking Jul 24, 2021 ...
# checking Jul 23, 2021 ...
# checking Jul 22, 2021 ...
# checking Jul 21, 2021 ...
# checking Jul 20, 2021 ...
# checking Jul 19, 2021 ...
# checking Jul 18, 2021 ...
# checking Jul 17, 2021 ...
# checking Jul 16, 2021 ...
# checking Jul 15, 2021 ...
# checking Jul 14, 2021 ...
# checking Jul 13, 2021 ...
# checking Jul 12, 2021 ...
# checking Jul 11, 2021 ...
# checking Jul 10, 2021 ...
# checking Jul 09, 2021 ...
# checking Jul 08, 2021 ...
# checking Jul 07, 2021 ...
# checking Jul 06, 2021 ...
# checking Jul 05, 2021 ...
# checking Jul 04, 2021 ...
# checking Jul 03, 2021 ...
# checking Jul 02, 2021 ...
#          date    first   second
# 0  2021-08-28  219,019  139,112
# 1  2021-08-27  217,121  137,456
# 2  2021-08-26  213,188  133,495
# 3  2021-08-25  210,461  130,437
# 4  2021-08-24  208,704  129,260
# 5  2021-08-23  203,753  124,694
# 6  2021-08-22  203,233  123,827
# 7  2021-08-21  202,117  122,835
# 8  2021-08-20  197,963  117,405
# 9  2021-08-19  194,124  112,125
# 10 2021-08-18  192,325  110,697
# 11 2021-08-17  188,473  107,593
# 12 2021-08-16  186,398  104,819
# 13 2021-08-15  186,020  104,279
# 14 2021-08-14  185,330  103,014
# 15 2021-08-13  181,701   98,445
# 16 2021-08-12  180,795   97,035
# 17 2021-08-11  179,252   94,513
# 18 2021-08-10  178,484   93,380
# 19 2021-08-09  175,425   90,765
# 20 2021-08-08  174,961   89,739
# 21 2021-08-07  173,549   88,212
# 22 2021-08-06  171,540   86,247
# 23 2021-08-05  170,831   85,228
# 24 2021-08-04  169,974   84,043
# 25 2021-08-03  168,170   82,284
# 26 2021-08-02  164,048   79,341
# 27 2021-08-01  163,728   78,713
# 28 2021-07-31  162,249   76,910
# 29 2021-07-30  159,327   74,508
# 30 2021-07-29  158,586   73,361
# 31 2021-07-28  188,778   88,956
# 32 2021-07-27  186,533   87,180
# 33 2021-07-26  177,550   80,804
# 34 2021-07-25  177,252   80,691
# 35 2021-07-24  176,674   80,144
# 36 2021-07-23  176,051   79,250
# 37 2021-07-22  173,121   76,715
# 38 2021-07-21  172,313   75,941
# 39 2021-07-20  170,650   74,460
# 40 2021-07-19  161,807   68,264
# 41 2021-07-18  161,497   68,133
# 42 2021-07-17  160,939   67,331
# 43 2021-07-16  159,263   65,961
# 44 2021-07-15  158,406   64,995
# 45 2021-07-14  156,854   63,580
# 46 2021-07-13  155,119   62,082
# 47 2021-07-12  151,868   59,392
# 48 2021-07-11  151,602   58,931
# 49 2021-07-10  150,940   58,429
# 50 2021-07-09  148,365   56,751
# 51 2021-07-08  147,570   55,752
# 52 2021-07-07  144,453   54,496
# 53 2021-07-06  143,625   53,654
# 54 2021-07-05  139,541   50,816
# 55 2021-07-04  139,124   50,219
# 56 2021-07-03  138,624   49,843
# 57 2021-07-02  135,464   47,464

# %%
date = pd.to_datetime("2021-07-01")

# begin cycle
print(f"checking {date:%b %d, %Y} ...")
url = f"https://www.health.gov.au/sites/default/files/documents/{date:%Y}/{date:%m}/covid-19-vaccine-rollout-update-{date:%-d-%B-%Y}.pdf".lower()
request = requests.get(url)
file = io.BytesIO(request.content)
reader = PdfFileReader(file)
contents = reader.getPage(5).extractText().split("\n")

print(contents)
# Out:
# checking Jul 01, 2021 ...
# ['VIC', 'QLD', 'WA', 'TAS', 'SA', 'ACT', 'NT', 'NSW', 'Aged care and residential      ', 'disability doses administered', 'First doses', 'Second doses', 'Residential aged care  ', 'facilities', 'Sites visited for first doses', 'Sites visited for second doses', 'Commonwealth aged care doses administered', 'Number of doses administered as part of the Commonwealth aged and disability care rollout', 'Data as at:', '18 Apr 2021', '230,986', '204,226', '435,212', 'Total vaccine doses administered in aged ', 'care and disability facilities as at ', '30 June', '135,602', '119,936', '82,314', '38,721', '35,988', '12,562', '7,395', '2,694', '(+', '774 ', 'last', '24 hours)', '(+', '562 ', 'last', '24 hours)', '(+', '566 ', 'last', '24 hours)', '(+', '232 ', 'last', '24 hours)', '(+', '246 ', 'last', '24 hours)', '(+', '117 ', 'last', '24 hours)', '(+', '18 ', 'last', '24 hours)', '(+', '54 ', 'last', '24 hours)', 'Data as at:', '30 Jun 2021', '2,566', '2,561', '(+2,569 last 24 hours)', '']
